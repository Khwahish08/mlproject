# %% [markdown]
# <a href="https://colab.research.google.com/github/Khwahish08/mlproject/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')
credit_card_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
(492/284808)*100
# Out:
# 0.17274795651807534

# %%
# 0--> Normal Transaction
# 1--> Fraud Transaction

# %%
valid = credit_card_data[credit_card_data.Class ==0]
fraud = credit_card_data[credit_card_data.Class ==1]

# %%
valid.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
valid_sample = valid.sample(n = 492)

# %%
new_data = pd.concat([valid_sample, fraud], axis =0)

# %%
new_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 79307    57963.0  1.191549 -0.350830  0.927819 -0.522027 -1.329786 -1.121739
# 51520    44994.0 -1.723904 -4.793097 -0.414835  2.612057 -2.504785  0.239413
# 13807    24472.0  1.480589 -1.146728  0.177691 -1.448683 -1.049691  0.228978
# 251110  155221.0  0.036408  0.805549  0.273385 -0.573730  0.315859 -1.131907
# 269286  163615.0 -0.446366 -0.370344  0.817056 -1.127854 -0.707276  0.195986
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94097.447154  0.033386 -0.084542 -0.026745  0.007214  0.022976
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.018970  0.031929  0.046321 -0.003643  ... -0.037660 -0.053875
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.033748  0.017664 -0.004964  0.029999  0.021906 -0.020687  0.015885
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.324431
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_data.drop('Class', axis =1)
Y = new_data['Class']

# %%
X.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 79307    57963.0  1.191549 -0.350830  0.927819 -0.522027 -1.329786 -1.121739
# 51520    44994.0 -1.723904 -4.793097 -0.414835  2.612057 -2.504785  0.239413
# 13807    24472.0  1.480589 -1.146728  0.177691 -1.448683 -1.049691  0.228978
# 251110  155221.0  0.036408  0.805549  0.273385 -0.573730  0.315859 -1.131907
# 269286  163615.0 -0.446366 -0.370344  0.817056 -1.127854 -0.707276  0.195986
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 79307  -0.397409 -0.140876  1.758665  ... -0.096970  0.149961  0.773305
# 51520   1.378201 -0.262337  0.664647  ...  2.847887  0.886175 -0.740709
# 13807  -1.352559  0.139740 -0.408826  ... -0.505115 -0.363269 -0.531959
# 251110  0.994458 -0.172223  0.054958  ... -0.069438 -0.264299 -0.625595
# 269286  0.776434  0.027380  0.200838  ...  0.596555  0.468157  1.096185
#
# ...

# %%
Y.head()
# Out:
# 79307     0
# 51520     0
# 13807     0
# 251110    0
# 269286    0
# Name: Class, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=3)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Training data's accuracy : ", training_data_accuracy)
# Out:
# Training data's accuracy :  0.940279542566709

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Test data's accuracy score : ", test_data_accuracy)
# Out:
# Test data's accuracy score :  0.9593908629441624

# %%
precision = precision_score(Y_test, X_test_prediction, average='weighted')
recall = recall_score(Y_test, X_test_prediction, average='weighted')
f1 = f1_score(Y_test, X_test_prediction, average='weighted')

# %%
print('Precision : ', precision)
# Out:
# Precision :  0.9610902670492165

# %%
print('Recall : ', recall)
# Out:
# Recall :  0.9593908629441624

# %%
print('F1 score : ', f1)
# Out:
# F1 score :  0.9593468592352785
